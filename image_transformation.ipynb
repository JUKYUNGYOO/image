# %% [markdown]
# <a href="https://colab.research.google.com/github/JUKYUNGYOO/image/blob/master/image_transformation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c5455c0a-9b2a-4ede-8152-94cb28b205d8" name="files[]" multiple disabled />
#      <output id="result-c5455c0a-9b2a-4ede-8152-94cb28b205d8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving cat.jpg to cat.jpg

# %% [markdown]
# 이미지 위치 변형
#
#
#
# ```
# #
# 1(a) 0     tx
# 0    1(b)  ty
# ```
#
#
# a,b -> (a+tx,b+ty)

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

image = cv2.imread('cat.jpg')

# 행과 열 정보만 저장
height, width= image.shape[:2]
# 오른쪽으로 50만큼 위에서 10 만큼 이동 
M = np.float32([[1,0,50],[0,1,10]])
dst = cv2.warpAffine(image,M,(width,height))

plt.imshow(cv2.cvtColor(dst,cv2.COLOR_BGR2RGB))
plt.show()

# %% [markdown]
# ```
# # 코드로 형식 지정됨
# cv2.getRotationMatrix2D(center,angle,scale)
# 이미지 회전을 위한 변환 행렬 생성
# center : 회전 중심
# angle : 회전 각도
# scale : Scale Factor
# ```

# %%
import cv2
import numpy as np 
import matplotlib.pyplot as plt

image = cv2.imread('cat.jpg')

# 행과 열 정보만 저장

height,width = image.shape[:2]
# 정중앙 기준,90도 회전 
# scale = 0.5 크기를 반으로 줄임 
M = cv2.getRotationMatrix2D((width/2,height/2),90,0.5)
dst = cv2.warpAffine(image,M,(width,height))

plt.imshow(cv2.cvtColor(dst,cv2.COLOR_BGR2RGB))
plt.show()
